# %% [markdown]
# # 爬取 Google Scholar、 AceMap 和 Altmetric 引用数据

# %% [markdown]
# ## Altmetric API 需要的论文编码
#
# |idtype|idnumber example|
# |:---:|:---:|
# |'id'|"108989"|
# |'doi'|"10.1126/science.1173146"|
# |'ads'|"2009sci...325..578w"|
# |'arxiv'|"1212.4819"|
# |'pmid'|"19644114"|

# %%
from altmetric import Altmetric
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd

# %%
# select Altmetric data
def selected_altmetric_items(rsp):
    all_rank = rsp['context']['all']['rank']/rsp['context']['all']['count']
    journal_rank = rsp['context']['journal']['rank']/rsp['context']['journal']['count']
    return [rsp['score'],
            round(all_rank,2),
            round(journal_rank,2),
            rsp['details_url']]

# %%
# get Altmetric data, and return as list with 4 members
def get_altmetric(title, idtype, idnumber):
    # get Altmetric data dict
    a = Altmetric(apikey='', apiver='v1')
    try:
        rsp = eval('a.' + idtype + '("' + idnumber + '")')
        if rsp is None:
            print("There is no '{}' in AceMap".format(title))
            return [None]*4
        else:
            return selected_altmetric_items(rsp)
    except [AltmetricHTTPException, e]:
        if e.status_code == 403:
            print("You aren't authorized for this call")
        elif e.status_code == 420:
            print("You are being rate limited")
        elif e.status_code == 502:
            print("The API version you are using is currently down for maintenance.")
        elif e.status_code == 404:
            print("Invalid API function")
            print(e.msg)

# %%
# get website text
def getHtml(url):
    try:
        req=requests.get(url)
        #if not 200，then raise error
        req.raise_for_status()
        req.encoding=req.apparent_encoding
        return req.text
    except:
        return "raise Error"

# %%
# get acemap citation
def get_acemap_citation(title):
    url = 'http://acemap.sjtu.edu.cn/result?q=' + title
    text = getHtml(url)
    soup = BeautifulSoup(text, "html.parser")
    # find the paper's title
    a_list = soup.find_all('a',href=re.compile('/paper'))
    count = 0
    for i in a_list:
        count += 1
        # check the title
        if i.text.capitalize() == title:
            # find the citation corresponding to title
            citation = soup.find_all('span',class_='ace_result_citations_year')[count*2-1].text
            return citation[12:]
    print("There is no '{}' in AceMap".format(title))

# %%
def get_gs_citation(title):
    url = 'https://scholar.google.com/scholar?q=' + title
    text = getHtml(url)
    soup = BeautifulSoup(text, "html.parser")
    # find the result item
    div_list = soup.find_all('div', class_="gs_ri")
    for i in div_list:
        # check the title
        if i.h3.text.capitalize() == title:
            # find the citation of the item
            is_citation = i.find(href=re.compile("/scholar\?cites"))
            if is_citation != None:
                citation = is_citation.text[9:] 
            else:
                citation = None
                print("There is no citation of '{}' in Google Scholar".format(title))
            return citation
    print("There is no '{}' in Google Scholar".format(title))

# %%
# get citation list
def get_citations_list(title, year, idtype, idnumber):
    title = title.capitalize()
    citations = get_altmetric(title, idtype, idnumber)
    for i in get_acemap_citation(title) ,get_gs_citation(title), year, title:
        citations.insert(0, i)
    return citations

# %%
# main func that get citation of each item
def get_citations_df(papers):
    citations = pd.DataFrame(columns=range(7))
    for i in papers:
        citation_list = get_citations_list(i[0], i[1], i[2], i[3])
        citations = citations.append(pd.DataFrame(citation_list).T)
    citations.rename(columns={0: 'title',
                              1: 'publish_year',
                              2: 'gs_citation',
                              3: 'acemap_citation',
                              4: 'altmetric_score',
                              5: 'top_all',
                              6: 'top_journal',
                              7:'altmetric_url'},
                    inplace=True)
    citations.set_index('title', inplace=True)
    citations.dropna(axis=0, how='all', inplace=True)
    return citations

# %%
import json

# %%
# get the paper imformations including title, publish year, idtype and idnumber
# the json file is export from Zotero in CLS JSON style
with open("MLS.json",'r') as load_f:
    load_dict = json.load(load_f)
    papers = []
    for i in load_dict:
        title = i['title']
        year = i['issued']['date-parts'][0][0]
        if i.get('DOI') != None:
            idtype = 'doi'
            idnumber = i['DOI']
        elif i.get('URL','').startswith('http://arxiv.org/abs/'):
            idtype = 'arxiv'
            idnumber = i['URL'].strip('http://arxiv.org/abs/')
        papers.append([title, year, idtype, idnumber])

# %%
df = get_citations_df(papers)
df
# Out:
# There is no 'A review of machine learning for automated planning' in AceMap
# There is no 'Regret analysis of stochastic and nonstochastic multi-armed bandit problems' in AceMap
# There is no 'Approximate policy iteration: a survey and some new methods' in AceMap
# There is no 'Approximate policy iteration: a survey and some new methods' in AceMap
# There is no 'Representation learning: a review and new perspectives' in AceMap
# There is no 'Two faces of active learning' in AceMap
# There is no 'Discrete wavelet transform-based time series analysis and mining' in AceMap
# There is no 'A comparative study of palmprint recognition algorithms' in AceMap
# There is no 'A survey of emerging approaches to spam filtering' in AceMap
# There is no 'Time-series data mining' in AceMap
# There is no 'Human activity analysis: a review' in AceMap
# There is no 'Xml data clustering: an overview' in AceMap
# There is no 'Ontology learning from text: a look back and into the future' in AceMap
# There is no 'Subspace methods for face recognition' in AceMap
# There is no 'Subspace methods for face recognition' in AceMap
# There is no 'Auctions and bidding: a guide for computer scientists' in AceMap
# There is no 'Auctions and bidding: a guide for computer scientists' in AceMap
# There is no 'Computational epigenetics: the new scientific paradigm' in AceMap
# There is no 'Computational epigenetics: the new scientific paradigm' in AceMap
# There is no 'Computational epigenetics: the new scientific paradigm' in Google Scholar
#                                                    publish_year gs_citation  \
# title
# Context based object categorization: a critical...         2010         281
# A review of machine learning for automated plan...         2012          42
# Regret analysis of stochastic and nonstochastic...         2012         909
# Kernels for vector-valued functions: a review              2011         204
# An introduction to conditional random fields               2010         704
# Randomized algorithms for matrices and data                2011         440
# A few useful things to know about machine learning         2012        1045
# Translation techniques in cross-language inform...         2012          45
# Approximate policy iteration: a survey and some...         2011         129
# Representation learning: a review and new persp...         2012        3185
# A tutorial on bayesian nonparametric models                2012         303
# Two faces of active learning                               2011         127
# Machine transliteration survey                             2011          66
# Discrete wavelet transform-based time series an...         2011          85
# A comparative study of palmprint recognition al...         2012         146
# A survey of emerging approaches to spam filtering          2012          76
# A review on time series data mining                        2011         722
# Time-series data mining                                    2012         409
# A survey of online failure prediction methods              2010         427
# A taxonomy of sequential pattern mining algorithms         2010         321
# Human activity analysis: a review                          2011        1656
# Xml data clustering: an overview                           2011          63
# Ambient intelligence: a survey                             2011         316
# Ontology learning from text: a look back and in...         2012         273
# Subspace methods for face recognition                      2010          43
# Probabilistic topic models                                 2012        2408
# Computer poker: a review                                   2011          81
# Auctions and bidding: a guide for computer scie...         2011         145
# Computational epigenetics: the new scientific p...         2010        None
# A survey on transfer learning                              2010        3983
# Data clustering: 50 years beyond k-means                   2010        4472
# Community detection in graphs                              2010        6592
# Pedestrian detection: an evaluation of the stat...         2012        1805
#
#                                                    acemap_citation  \
# title
# Context based object categorization: a critical...              81
# A review of machine learning for automated plan...               4
# Regret analysis of stochastic and nonstochastic...            None
# Kernels for vector-valued functions: a review                   21
# An introduction to conditional random fields                    61
# Randomized algorithms for matrices and data                     37
# A few useful things to know about machine learning             110
# Translation techniques in cross-language inform...              77
# Approximate policy iteration: a survey and some...            None
# Representation learning: a review and new persp...            None
# A tutorial on bayesian nonparametric models                     50
# Two faces of active learning                                    26
# Machine transliteration survey                                 116
# Discrete wavelet transform-based time series an...              23
# A comparative study of palmprint recognition al...              28
# A survey of emerging approaches to spam filtering               18
# A review on time series data mining                            167
# Time-series data mining                                       None
# A survey of online failure prediction methods                   88
# A taxonomy of sequential pattern mining algorithms              71
# Human activity analysis: a review                              378
# Xml data clustering: an overview                                 7
# Ambient intelligence: a survey                                  82
# Ontology learning from text: a look back and in...            None
# Subspace methods for face recognition                         None
# Probabilistic topic models                                     194
# Computer poker: a review                                        20
# Auctions and bidding: a guide for computer scie...            None
# Computational epigenetics: the new scientific p...            None
# A survey on transfer learning                                  800
# Data clustering: 50 years beyond k-means                       545
# Community detection in graphs                                 1289
# Pedestrian detection: an evaluation of the stat...             312
#
#                                                    altmetric_score top_all  \
# title
# Context based object categorization: a critical...               6    0.17
# A review of machine learning for automated plan...            None    None
# Regret analysis of stochastic and nonstochastic...               3    0.27
# Kernels for vector-valued functions: a review                  4.5    0.22
# An introduction to conditional random fields                  15.7    0.07
# Randomized algorithms for matrices and data                   41.5    0.03
# A few useful things to know about machine learning           24.31    0.04
# Translation techniques in cross-language inform...           9.064    0.12
# Approximate policy iteration: a survey and some...            None    None
# Representation learning: a review and new persp...          99.316    0.01
# A tutorial on bayesian nonparametric models                   5.25     0.2
# Two faces of active learning                                  None    None
# Machine transliteration survey                                   3    0.27
# Discrete wavelet transform-based time series an...            None    None
# A comparative study of palmprint recognition al...            None    None
# A survey of emerging approaches to spam filtering             None    None
# A review on time series data mining                              5    0.21
# Time-series data mining                                         13    0.08
# A survey of online failure prediction methods                  6.5    0.16
# A taxonomy of sequential pattern mining algorithms             7.5    0.14
# Human activity analysis: a review                             None    None
# Xml data clustering: an overview                              None    None
# Ambient intelligence: a survey                                   3    0.25
# Ontology learning from text: a look back and in...               4    0.23
# Subspace methods for face recognition                         None    None
# Probabilistic topic models                                   96.07    0.01
# Computer poker: a review                                         3    0.23
# Auctions and bidding: a guide for computer scie...            None    None
# Computational epigenetics: the new scientific p...            None    None
# A survey on transfer learning                                  2.5    0.42
# Data clustering: 50 years beyond k-means                     11.75    0.09
# Community detection in graphs                               94.564    0.01
# Pedestrian detection: an evaluation of the stat...               9    0.12
#
#                                                    top_journal  \
# title
# Context based object categorization: a critical...        0.09
# A review of machine learning for automated plan...        None
# Regret analysis of stochastic and nonstochastic...        0.81
# Kernels for vector-valued functions: a review             0.11
# An introduction to conditional random fields              0.02
# Randomized algorithms for matrices and data               0.01
# A few useful things to know about machine learning        0.02
# Translation techniques in cross-language inform...        0.09
# Approximate policy iteration: a survey and some...        None
# Representation learning: a review and new persp...           0
# A tutorial on bayesian nonparametric models                0.2
# Two faces of active learning                              None
# Machine transliteration survey                            0.34
# Discrete wavelet transform-based time series an...        None
# A comparative study of palmprint recognition al...        None
# A survey of emerging approaches to spam filtering         None
# A review on time series data mining                       0.09
# Time-series data mining                                   0.07
# A survey of online failure prediction methods             0.19
# A taxonomy of sequential pattern mining algorithms        0.18
# Human activity analysis: a review                         None
# Xml data clustering: an overview                          None
# Ambient intelligence: a survey                            0.25
# Ontology learning from text: a look back and in...        0.37
# Subspace methods for face recognition                     None
# Probabilistic topic models                                   0
# Computer poker: a review                                  0.14
# Auctions and bidding: a guide for computer scie...        None
# Computational epigenetics: the new scientific p...        None
# A survey on transfer learning                             0.26
# Data clustering: 50 years beyond k-means                  0.01
# Community detection in graphs                                0
# Pedestrian detection: an evaluation of the stat...        0.04
#
#                                                                                         altmetric_url
# title
# Context based object categorization: a critical...  http://www.altmetric.com/details.php?citation_...
# A review of machine learning for automated plan...                                               None
# Regret analysis of stochastic and nonstochastic...  http://www.altmetric.com/details.php?citation_...
# Kernels for vector-valued functions: a review       http://www.altmetric.com/details.php?citation_...
# An introduction to conditional random fields        http://www.altmetric.com/details.php?citation_...
# Randomized algorithms for matrices and data         http://www.altmetric.com/details.php?citation_...
# A few useful things to know about machine learning  http://www.altmetric.com/details.php?citation_...
# Translation techniques in cross-language inform...  http://www.altmetric.com/details.php?citation_...
# Approximate policy iteration: a survey and some...                                               None
# Representation learning: a review and new persp...  http://www.altmetric.com/details.php?citation_...
# A tutorial on bayesian nonparametric models         http://www.altmetric.com/details.php?citation_...
# Two faces of active learning                                                                     None
# Machine transliteration survey                      http://www.altmetric.com/details.php?citation_...
# Discrete wavelet transform-based time series an...                                               None
# A comparative study of palmprint recognition al...                                               None
# A survey of emerging approaches to spam filtering                                                None
# A review on time series data mining                 http://www.altmetric.com/details.php?citation_...
# Time-series data mining                             http://www.altmetric.com/details.php?citation_...
# A survey of online failure prediction methods       http://www.altmetric.com/details.php?citation_...
# A taxonomy of sequential pattern mining algorithms  http://www.altmetric.com/details.php?citation_...
# Human activity analysis: a review                                                                None
# Xml data clustering: an overview                                                                 None
# Ambient intelligence: a survey                      http://www.altmetric.com/details.php?citation_...
# Ontology learning from text: a look back and in...  http://www.altmetric.com/details.php?citation_...
# Subspace methods for face recognition                                                            None
# Probabilistic topic models                          http://www.altmetric.com/details.php?citation_...
# Computer poker: a review                            http://www.altmetric.com/details.php?citation_...
# Auctions and bidding: a guide for computer scie...                                               None
# Computational epigenetics: the new scientific p...                                               None
# A survey on transfer learning                       http://www.altmetric.com/details.php?citation_...
# Data clustering: 50 years beyond k-means            http://www.altmetric.com/details.php?citation_...
# Community detection in graphs                       http://www.altmetric.com/details.php?citation_...
# Pedestrian detection: an evaluation of the stat...  http://www.altmetric.com/details.php?citation_...

# %% [markdown]
# 参考：
# * [GitHub - lnielsen/python-altmetric: Altmetric API v1 wrapper for Python](https://github.com/lnielsen/python-altmetric)
# * [Altmetric API Support – Altmetric](https://www.altmetric.com/support/almetric-api/)
# * [Getting Started | Altmetric API documentation](http://api.altmetric.com/)
